# %%
from roboflow import Roboflow
rf = Roboflow(api_key="LKpJxtT40ymEscOdU7jX")
project = rf.workspace("s-workspace-iiedp").project("strawposesmall")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolo26 in progress : 0.0%
# Version export complete for yolo26 format
# ...
# Extracting Dataset Version Zip to StrawPoseSmall-1 in yolo26:: 100%|██████████| 121/121 [00:00<00:00, 2514.83it/s]
